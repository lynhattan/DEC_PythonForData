# %% [markdown]
# - Yêu cầu thống kê (visualize dữ liệu nếu có thể):
#     - Các hãng đang cung cấp Card đồ họa, số lượng sản phẩm của mỗi hãng.
#     - Phân bố giá của các sản phẩm (Mức giá phổ biến là bao nhiêu)
#     - Phân bố giá sản phẩm theo hãng
#     - Biểu diễn mối liên hệ giữa giá sản phẩm và rating của người dùng

# %%
# import libraries

from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Credentials to database connection
hostname="localhost"
dbname="db_project2"
uname="tanlee"
pwd="17012021*Th"


# Create SQLAlchemy engine to connect to MySQL Database

engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}" \
                       .format(host=hostname, db=dbname, user=uname, pw=pwd))

# Retrieve data from MysQL database

df = pd.read_sql_query("select * from products", engine)
df.head()
# Out:
#           item_id                                              title  \
# 0      14-932-580  GIGABYTE GeForce RTX 4070 Ti GAMING OC 12G Gra...
# 1      14-932-561  GIGABYTE Gaming GeForce RTX 4080 16GB GDDR6X P...
# 2  9SIB86XH2K2757  51Risc AMD Radeon RX 580 DirectX 12 RX580 8G 2...
# 3      14-932-562  GIGABYTE EAGLE OC GeForce RTX 4080 16GB GDDR6X...
# 4      14-137-765  MSI Ventus GeForce RTX 4080 16GB GDDR6X PCI Ex...
#
#       brand rating number_of_rating  price_current       shipping  \
# 0  GIGABYTE    4.9               59          848.4  Free Shipping
# 1  GIGABYTE    4.3              109         1199.4  Free Shipping
# 2    51Risc    4.6               18           85.4  Free Shipping
# 3  GIGABYTE      4               41         1189.4  Free Shipping
# 4       MSI    4.6               35         1199.4  Free Shipping
#
#                                            image_url  \
# 0  https://c1.neweggimages.com/ProductImageCompre...
# 1  https://c1.neweggimages.com/ProductImageCompre...
# 2  https://c1.neweggimages.com/ProductImageCompre...
# 3  https://c1.neweggimages.com/ProductImageCompre...
# 4  https://c1.neweggimages.com/ProductImageCompre...
#
#                                              details  total_price
# 0  {'Max_Resolution': ' 7680 x 4320', 'Display_Po...        848.4
# 1  {'Max_Resolution': ' 7680 x 4320', 'Display_Po...       1199.4
# 2  {'Max_Resolution': ' 4096 x 2160', 'Display_Po...         85.4
# 3  {'Max_Resolution': ' 7680 x 4320', 'Display_Po...       1189.4
# 4  {'Max_Resolution': ' 7680 x 4320', 'Display_Po...       1199.4

# %%
df.describe()
# Out:
#        price_current  total_price
# count    3604.000000  3604.000000
# mean      598.896396   607.032777
# std       488.718991   488.756282
# min         0.000000    24.000000
# 25%       269.990000   279.000000
# 50%       469.000000   485.890000
# 75%       749.520000   749.990000
# max      5239.750000  5239.750000

# %%
df.dtypes
# Out:
# item_id              object
# title                object
# brand                object
# rating               object
# number_of_rating     object
# price_current       float64
# shipping             object
# image_url            object
# details              object
# total_price         float64
# dtype: object

# %% [markdown]
# ## 1. Các hãng đang cung cấp Card đồ họa, số lượng sản phẩm của mỗi hãng.

# %%
fig = plt.figure(figsize = (10, 5))
x = df['brand'].unique()
y = df['brand'].value_counts()

plt.bar(x, y, color='maroon', width= 0.5)
plt.xlabel("Branding")
plt.ylabel('Number of cards')
plt.title('Branding vs No.of Cards', fontsize=20, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2. Phân bố giá của các sản phẩm (Mức giá phổ biến là bao nhiêu)

# %%
fig = plt.figure(figsize = (10, 5))

plt.hist(df['total_price'], color='blue', ec='black', bins=10)
plt.title('Distribution of total price',fontweight="bold", fontsize=20)
plt.xlabel('Price ($)')
# Out:
# Text(0.5, 0, 'Price ($)')

# %%
fig = plt.figure(figsize = (10, 5))
plt.boxplot([df['total_price'], df['price_current']], patch_artist=True, \
            labels=['Price include shipping fee', 'Price not include shipping fee'])
plt.ylabel('Price ($)')
plt.title('Distribution of price', fontweight="bold", fontsize=20)
plt.show()

# %% [markdown]
# ## 3. Phân bố giá sản phẩm theo hãng

# %%
fig = plt.figure(figsize = (10, 5))
x = df['brand'].unique()
y = df.groupby(by='brand').mean()['total_price'].sort_values(ascending=False)

plt.bar(x, y, color='maroon', width= 0.5)
plt.xlabel("Branding")
plt.ylabel('Price')
plt.title('Distribution of Branding vs Price', fontsize=20, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 4. Biểu diễn mối liên hệ giữa giá sản phẩm và rating của người dùng

# %%
fig = plt.figure(figsize = (10, 5))

x = df['rating'].unique()
y = df.groupby(by='rating').mean()['total_price'].sort_values(ascending=False)

plt.bar(x, y, color='green', width= 0.5)
plt.xlabel("Rating")
plt.ylabel('Price ($)')
plt.title('Rating vs Price', fontsize=20, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))

x = df['rating'].unique()
y = df.groupby(by='rating').mean()['total_price']

plt.scatter(x, y)
plt.title('Relationship of Rating vs Price', fontsize=20, fontweight='bold')
plt.xticks(rotation=90, size='large')
plt.xlabel('Rating')
plt.ylabel('Price ($)')
plt.show()

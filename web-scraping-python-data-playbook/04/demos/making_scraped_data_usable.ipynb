# %% [markdown]
# # Making Scraped Data Usable

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
SCRAPED_CSV = 'scraped_cars.csv'

# %% [markdown]
# ## Load CSV and Review

# %%
df_raw = pd.read_csv(SCRAPED_CSV)
df = df_raw.copy() # keep a defensive copy of the original data
df.head()
# Out:
#                         name  cylinders  weight  year territory  acceleration  \
# 0  Chevrolet Chevelle Malibu          8    3504  1970       USA          12.0
# 1          Buick Skylark 320          8    3693  1970       USA          11.5
# 2         Plymouth Satellite          8    3436  1970       USA          11.0
# 3              Amc Rebel Sst          8    3433  1970       USA          12.0
# 4                Ford Torino          8    3449  1970       USA          10.5
#
#     mpg     hp  displacement
# 0  18.0  130.0         307.0
# 1  15.0  165.0         350.0
# 2  18.0  150.0         318.0
# 3  16.0  150.0         304.0
# 4  17.0  140.0         302.0

# %%
df.shape
# Out:
# (406, 9)

# %%
df.sample(5)
# Out:
#                   name  cylinders  weight  year territory  acceleration   mpg  \
# 349   Plymouth Reliant          4    2385  1981       USA          12.9  30.0
# 399  Dodge Charger 2.2          4    2370  1982       USA          13.0  36.0
# 79    Amc Matador (Sw)          8    3892  1972       USA          12.5  15.0
# 173    Ford Mustang Ii          8    3169  1975       USA          12.0  13.0
# 351     Plymouth Champ          4    1875  1981       USA          16.4  39.0
#
#         hp  displacement
# 349   84.0         135.0
# 399   84.0         135.0
# 79   150.0         304.0
# 173  129.0         302.0
# 351   64.0          86.0

# %%
df.describe()
# Out:
#         cylinders       weight         year  acceleration         mpg  \
# count  406.000000   406.000000   406.000000    406.000000  398.000000
# mean     5.475369  2979.413793  1975.921182     15.519704   23.514573
# std      1.712160   847.004328     3.748737      2.803359    7.815984
# min      3.000000  1613.000000  1970.000000      8.000000    9.000000
# 25%      4.000000  2226.500000  1973.000000     13.700000   17.500000
# 50%      4.000000  2822.500000  1976.000000     15.500000   23.000000
# 75%      8.000000  3618.250000  1979.000000     17.175000   29.000000
# max      8.000000  5140.000000  1982.000000     24.800000   46.600000
#
#                hp  displacement
# count  400.000000    406.000000
# mean   105.082500    194.779557
# std     38.768779    104.922458
# min     46.000000     68.000000
# 25%     75.750000    105.000000
# 50%     95.000000    151.000000
# 75%    130.000000    302.000000
# max    230.000000    455.000000

# %% [markdown]
# ## Data Review Strategy

# %%
df.territory.value_counts()
# Out:
# USA       254
# Japan      79
# Europe     73
# Name: territory, dtype: int64

# %%
df.cylinders.value_counts()
# Out:
# 4    207
# 8    108
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df.cylinders.value_counts().sort_index()
# Out:
# 3      4
# 4    207
# 5      3
# 6     84
# 8    108
# Name: cylinders, dtype: int64

# %%
ax = sns.countplot(data=df, y='cylinders')
ax.set_title("Counts for Each Cylinder Type");

# %%
ax = sns.countplot(data=df, x='year')
ax.set_title('Counts of Cars per Year');
plt.xticks(rotation=45);

# %%
df.isnull().sum()
# Out:
# name            0
# cylinders       0
# weight          0
# year            0
# territory       0
# acceleration    0
# mpg             8
# hp              6
# displacement    0
# dtype: int64

# %%
df.mpg.isnull()[5:15]
# Out:
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# Name: mpg, dtype: bool

# %%
df[df.mpg.isnull()]
# Out:
#                                  name  cylinders  weight  year territory  \
# 10               Citroen Ds-21 Pallas          4    3090  1970    Europe
# 11   Chevrolet Chevelle Concours (Sw)          8    4142  1970       USA
# 12                   Ford Torino (Sw)          8    4034  1970       USA
# 13            Plymouth Satellite (Sw)          8    4166  1970       USA
# 14                 Amc Rebel Sst (Sw)          8    3850  1970       USA
# 17              Ford Mustang Boss 302          8    3353  1970       USA
# 39        Volkswagen Super Beetle 117          4    1978  1971    Europe
# 367                         Saab 900S          4    2800  1981    Europe
#
#      acceleration  mpg     hp  displacement
# 10           17.5  NaN  115.0         133.0
# 11           11.5  NaN  165.0         350.0
# 12           11.0  NaN  153.0         351.0
# 13           10.5  NaN  175.0         383.0
# 14           11.0  NaN  175.0         360.0
# 17            8.0  NaN  140.0         302.0
# 39           20.0  NaN   48.0          97.0
# 367          15.4  NaN  110.0         121.0

# %%
df[df.hp.isnull()]
# Out:
#                      name  cylinders  weight  year territory  acceleration  \
# 38             Ford Pinto          4    2046  1971       USA          19.0
# 133         Ford Maverick          6    2875  1974       USA          17.0
# 337  Renault Lecar Deluxe          4    1835  1980    Europe          17.3
# 343    Ford Mustang Cobra          4    2905  1980       USA          14.3
# 361           Renault 18I          4    2320  1981    Europe          15.8
# 382        Amc Concord Dl          4    3035  1982       USA          20.5
#
#       mpg  hp  displacement
# 38   25.0 NaN          98.0
# 133  21.0 NaN         200.0
# 337  40.9 NaN          85.0
# 343  23.6 NaN         140.0
# 361  34.5 NaN         100.0
# 382  23.0 NaN         151.0

# %%
def highlight_max(s):
    '''Highlight the maximum in a Series yellow'''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df.pivot_table(index=['year'], aggfunc='count').style.apply(highlight_max, axis=1)
# Out:
# <style type="text/css">
# #T_cbfc5_row0_col0, #T_cbfc5_row0_col1, #T_cbfc5_row0_col2, #T_cbfc5_row0_col3, #T_cbfc5_row0_col5, #T_cbfc5_row0_col6, #T_cbfc5_row0_col7, #T_cbfc5_row1_col0, #T_cbfc5_row1_col1, #T_cbfc5_row1_col2, #T_cbfc5_row1_col5, #T_cbfc5_row1_col6, #T_cbfc5_row1_col7, #T_cbfc5_row2_col0, #T_cbfc5_row2_col1, #T_cbfc5_row2_col2, #T_cbfc5_row2_col3, #T_cbfc5_row2_col4, #T_cbfc5_row2_col5, #T_cbfc5_row2_col6, #T_cbfc5_row2_col7, #T_cbfc5_row3_col0, #T_cbfc5_row3_col1, #T_cbfc5_row3_col2, #T_cbfc5_row3_col3, #T_cbfc5_row3_col4, #T_cbfc5_row3_col5, #T_cbfc5_row3_col6, #T_cbfc5_row3_col7, #T_cbfc5_row4_col0, #T_cbfc5_row4_col1, #T_cbfc5_row4_col2, #T_cbfc5_row4_col4, #T_cbfc5_row4_col5, #T_cbfc5_row4_col6, #T_cbfc5_row4_col7, #T_cbfc5_row5_col0, #T_cbfc5_row5_col1, #T_cbfc5_row5_col2, #T_cbfc5_row5_col3, #T_cbfc5_row5_col4, #T_cbfc5_row5_col5, #T_cbfc5_row5_col6, #T_cbfc5_row5_col7, #T_cbfc5_row6_col0, #T_cbfc5_row6_col1, #T_cbfc5_row6_col2, #T_cbfc5_row6_col3, #T_cbfc5_row6_col4, #T_cbfc5_row6_col5, #T_cbfc5_row6_col6, #T_cbfc5_row6_col7, #T_cbfc5_row7_col0, #T_cbfc5_row7_col1, #T_cbfc5_row7_col2, #T_cbfc5_row7_col3, #T_cbfc5_row7_col4, #T_cbfc5_row7_col5, #T_cbfc5_row7_col6, #T_cbfc5_row7_col7, #T_cbfc5_row8_col0, #T_cbfc5_row8_col1, #T_cbfc5_row8_col2, #T_cbfc5_row8_col3, #T_cbfc5_row8_col4, #T_cbfc5_row8_col5, #T_cbfc5_row8_col6, #T_cbfc5_row8_col7, #T_cbfc5_row9_col0, #T_cbfc5_row9_col1, #T_cbfc5_row9_col2, #T_cbfc5_row9_col3, #T_cbfc5_row9_col4, #T_cbfc5_row9_col5, #T_cbfc5_row9_col6, #T_cbfc5_row9_col7, #T_cbfc5_row10_col0, #T_cbfc5_row10_col1, #T_cbfc5_row10_col2, #T_cbfc5_row10_col4, #T_cbfc5_row10_col5, #T_cbfc5_row10_col6, #T_cbfc5_row10_col7, #T_cbfc5_row11_col0, #T_cbfc5_row11_col1, #T_cbfc5_row11_col2, #T_cbfc5_row11_col5, #T_cbfc5_row11_col6, #T_cbfc5_row11_col7, #T_cbfc5_row12_col0, #T_cbfc5_row12_col1, #T_cbfc5_row12_col2, #T_cbfc5_row12_col4, #T_cbfc5_row12_col5, #T_cbfc5_row12_col6, #T_cbfc5_row12_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_cbfc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbfc5_level0_col0" class="col_heading level0 col0" >acceleration</th>
#       <th id="T_cbfc5_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_cbfc5_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_cbfc5_level0_col3" class="col_heading level0 col3" >hp</th>
#       <th id="T_cbfc5_level0_col4" class="col_heading level0 col4" >mpg</th>
#       <th id="T_cbfc5_level0_col5" class="col_heading level0 col5" >name</th>
#       <th id="T_cbfc5_level0_col6" class="col_heading level0 col6" >territory</th>
#       <th id="T_cbfc5_level0_col7" class="col_heading level0 col7" >weight</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbfc5_level0_row0" class="row_heading level0 row0" >1970</th>
#       <td id="T_cbfc5_row0_col0" class="data row0 col0" >35</td>
#       <td id="T_cbfc5_row0_col1" class="data row0 col1" >35</td>
#       <td id="T_cbfc5_row0_col2" class="data row0 col2" >35</td>
#       <td id="T_cbfc5_row0_col3" class="data row0 col3" >35</td>
#       <td id="T_cbfc5_row0_col4" class="data row0 col4" >29</td>
#       <td id="T_cbfc5_row0_col5" class="data row0 col5" >35</td>
#       <td id="T_cbfc5_row0_col6" class="data row0 col6" >35</td>
#       <td id="T_cbfc5_row0_col7" class="data row0 col7" >35</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row1" class="row_heading level0 row1" >1971</th>
#       <td id="T_cbfc5_row1_col0" class="data row1 col0" >29</td>
#       <td id="T_cbfc5_row1_col1" class="data row1 col1" >29</td>
#       <td id="T_cbfc5_row1_col2" class="data row1 col2" >29</td>
#       <td id="T_cbfc5_row1_col3" class="data row1 col3" >28</td>
#       <td id="T_cbfc5_row1_col4" class="data row1 col4" >28</td>
#       <td id="T_cbfc5_row1_col5" class="data row1 col5" >29</td>
#       <td id="T_cbfc5_row1_col6" class="data row1 col6" >29</td>
#       <td id="T_cbfc5_row1_col7" class="data row1 col7" >29</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row2" class="row_heading level0 row2" >1972</th>
#       <td id="T_cbfc5_row2_col0" class="data row2 col0" >28</td>
#       <td id="T_cbfc5_row2_col1" class="data row2 col1" >28</td>
#       <td id="T_cbfc5_row2_col2" class="data row2 col2" >28</td>
#       <td id="T_cbfc5_row2_col3" class="data row2 col3" >28</td>
#       <td id="T_cbfc5_row2_col4" class="data row2 col4" >28</td>
#       <td id="T_cbfc5_row2_col5" class="data row2 col5" >28</td>
#       <td id="T_cbfc5_row2_col6" class="data row2 col6" >28</td>
#       <td id="T_cbfc5_row2_col7" class="data row2 col7" >28</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row3" class="row_heading level0 row3" >1973</th>
#       <td id="T_cbfc5_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_cbfc5_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_cbfc5_row3_col2" class="data row3 col2" >40</td>
#       <td id="T_cbfc5_row3_col3" class="data row3 col3" >40</td>
#       <td id="T_cbfc5_row3_col4" class="data row3 col4" >40</td>
#       <td id="T_cbfc5_row3_col5" class="data row3 col5" >40</td>
#       <td id="T_cbfc5_row3_col6" class="data row3 col6" >40</td>
#       <td id="T_cbfc5_row3_col7" class="data row3 col7" >40</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row4" class="row_heading level0 row4" >1974</th>
#       <td id="T_cbfc5_row4_col0" class="data row4 col0" >27</td>
#       <td id="T_cbfc5_row4_col1" class="data row4 col1" >27</td>
#       <td id="T_cbfc5_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_cbfc5_row4_col3" class="data row4 col3" >26</td>
#       <td id="T_cbfc5_row4_col4" class="data row4 col4" >27</td>
#       <td id="T_cbfc5_row4_col5" class="data row4 col5" >27</td>
#       <td id="T_cbfc5_row4_col6" class="data row4 col6" >27</td>
#       <td id="T_cbfc5_row4_col7" class="data row4 col7" >27</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row5" class="row_heading level0 row5" >1975</th>
#       <td id="T_cbfc5_row5_col0" class="data row5 col0" >30</td>
#       <td id="T_cbfc5_row5_col1" class="data row5 col1" >30</td>
#       <td id="T_cbfc5_row5_col2" class="data row5 col2" >30</td>
#       <td id="T_cbfc5_row5_col3" class="data row5 col3" >30</td>
#       <td id="T_cbfc5_row5_col4" class="data row5 col4" >30</td>
#       <td id="T_cbfc5_row5_col5" class="data row5 col5" >30</td>
#       <td id="T_cbfc5_row5_col6" class="data row5 col6" >30</td>
#       <td id="T_cbfc5_row5_col7" class="data row5 col7" >30</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row6" class="row_heading level0 row6" >1976</th>
#       <td id="T_cbfc5_row6_col0" class="data row6 col0" >34</td>
#       <td id="T_cbfc5_row6_col1" class="data row6 col1" >34</td>
#       <td id="T_cbfc5_row6_col2" class="data row6 col2" >34</td>
#       <td id="T_cbfc5_row6_col3" class="data row6 col3" >34</td>
#       <td id="T_cbfc5_row6_col4" class="data row6 col4" >34</td>
#       <td id="T_cbfc5_row6_col5" class="data row6 col5" >34</td>
#       <td id="T_cbfc5_row6_col6" class="data row6 col6" >34</td>
#       <td id="T_cbfc5_row6_col7" class="data row6 col7" >34</td>
#     </tr>
#     <tr>
#       <th id="T_cbfc5_level0_row7" class="row_heading level0 row7" >1977</th>
#       <td id="T_cbfc5_row7_col0" class="data row7 col0" >28</td>
#       <td id="T_cbfc5_row7_col1" class="data row7 col1" >28</td>
#       <td id="T_cbfc5_row7_col2" class="data row7 col2" >28</td>
#       <td id="T_cbfc5_row7_col3" class="data row7 col3" >28</td>
#       <td id="T_cbfc5_row7_col4" class="data row7 col4" >28</td>
#       <td id="T_cbfc5_row7_col5" class="data row7 col5" >28</td>
#       <td id="T_cbfc5_row7_col6" c

# %%
print(f"Before we drop NaN rows we have {df.shape} rows")
df = df.dropna()
print(f"After we drop NaN rows we have {df.shape} rows")
# Out:
# Before we drop NaN rows we have (406, 9) rows
# After we drop NaN rows we have (392, 9) rows

# %%
df.cylinders.value_counts().sort_index()
# Out:
# 3      4
# 4    199
# 5      3
# 6     83
# 8    103
# Name: cylinders, dtype: int64

# %%
df = df.query("cylinders != 3 and cylinders != 5").copy()
df.cylinders.value_counts().sort_index()
# Out:
# 4    199
# 6     83
# 8    103
# Name: cylinders, dtype: int64

# %%
df['cylinders_label'] = df.cylinders.apply(lambda v: f"{v} cylinders")
df.cylinders_label.value_counts().sort_index()
# Out:
# 4 cylinders    199
# 6 cylinders     83
# 8 cylinders    103
# Name: cylinders_label, dtype: int64

# %% [markdown]
# ### What Distribution Does MPG Have?

# %%
print(f"Examples of MPG values: {list(df.mpg.sample(10).sort_values())}")
ax = df.mpg.hist()
ax.set_ylabel('Frequency')
ax.set_xlabel('Binned MPG')
ax.set_title('Histogram of Continuous MPG Values');
# Out:
# Examples of MPG values: [17.6, 19.0, 22.0, 22.0, 26.0, 27.2, 28.8, 29.0, 31.0, 32.0]

# %%
ax = df.weight.hist()
ax.set_ylabel('Frequency')
ax.set_xlabel('Binned Weight')
ax.set_title('Histogram of Continuous Weight (lbs) Values');

# %% [markdown]
# ## Reviewing Our Goal

# %%
df.pivot_table(index=['year'], aggfunc='mean')
# Out:
#       acceleration  cylinders  displacement          hp        mpg  \
# year
# 1970     12.948276   6.758621    281.413793  147.827586  17.689655
# 1971     15.000000   5.629630    213.888889  107.037037  21.111111
# 1972     15.185185   5.925926    223.870370  121.037037  18.703704
# 1973     14.333333   6.461538    261.666667  131.512821  17.076923
# 1974     16.173077   5.230769    170.653846   94.230769  22.769231
# 1975     16.050000   5.600000    205.533333  101.066667  20.266667
# 1976     15.941176   5.647059    197.794118  101.117647  21.573529
# 1977     15.507407   5.555556    195.518519  104.888889  23.444444
# 1978     15.802857   5.371429    179.142857   99.600000  24.168571
# 1979     15.660714   5.857143    207.535714  102.071429  25.082143
# 1980     17.084000   4.160000    117.720000   77.000000  34.104000
# 1981     16.325000   4.642857    136.571429   81.035714  30.185714
# 1982     16.510000   4.200000    128.133333   81.466667  32.000000
#
#            weight
# year
# 1970  3372.793103
# 1971  3030.592593
# 1972  3271.333333
# 1973  3452.230769
# 1974  2878.038462
# 1975  3176.800000
# 1976  3078.735294
# 1977  3007.629630
# 1978  2862.714286
# 1979  3038.392857
# 1980  2422.120000
# 1981  2530.178571
# 1982  2434.166667

# %% [markdown]
# ## What Correlates with MPG?

# %%
df.corr()['mpg'].sort_values()
# Out:
# weight         -0.842681
# displacement   -0.817887
# cylinders      -0.794872
# hp             -0.780259
# acceleration    0.419337
# year            0.579778
# mpg             1.000000
# Name: mpg, dtype: float64

# %% [markdown]
# ### Exploring MPG vs. Weight

# %%
ax = df.plot(kind="scatter", x='weight', y='mpg')
ax.set_title('Scatterplot of MPG vs. Weight (lbs)');

# %%
ax = df.plot(kind="scatter", x='weight', y='mpg', alpha=0.5)
ax.set_title('Scatterplot of MPG vs. Weight (lbs)');

# %%
jg = sns.jointplot(data=df, x='weight', y='mpg');
jg.fig.suptitle('Somewhat Non-linear Relationship between HP and Weight');

# %%
jg = sns.jointplot(data=df, x='weight', y='mpg').plot_joint(sns.kdeplot, zorder=0, n_levels=5)
jg.fig.suptitle('Density Estimate for MPG vs. Weight');

# %% [markdown]
# ### Exploring HP vs. Weight

# %%
ax = df.plot(kind="scatter", x='hp', y='weight')
ax.set_title('Reasonably Linear Relationship between HP and Weight');

# %%
jg = sns.jointplot(data=df, x='hp', y='weight', kind='reg')
jg.fig.suptitle('Reasonably Linear Relationship between HP and Weight');

# %%
df.query("hp > 200 and weight < 3500") # Fully equipped luxury entrant
# Out:
#                        name  cylinders  weight  year territory  acceleration  \
# 19  Buick Estate Wagon (Sw)          8    3086  1970       USA          10.0
#
#      mpg     hp  displacement cylinders_label
# 19  14.0  225.0         455.0     8 cylinders

# %% [markdown]
# ## Cylinders and Displacement

# %%
sorted_cylinders_label = df.cylinders_label.value_counts().sort_index().index
sorted_cylinders_label
# Out:
# Index(['4 cylinders', '6 cylinders', '8 cylinders'], dtype='object')

# %%
ax = df.plot(kind='scatter', x='cylinders', y='displacement')
ax.set_title("Scatterplot of Cylinders vs. Displacement");

# %%
ax = sns.stripplot(data=df, x='cylinders_label', y='displacement', order=sorted_cylinders_label)
ax.set_title("Stripplot of Cylinders vs. Displacement with Jitter");

# %%
ax = sns.boxplot(data=df, x='cylinders_label', y='weight', order=sorted_cylinders_label)
ax.set_title("Boxplot of Cylinders vs. Weight");

# %%
ax = sns.boxplot(data=df, x='cylinders_label', y='displacement', order=sorted_cylinders_label, notch=True) 
ax.set_title("Notched Boxplot of Cylinders vs. Weight");

# %% [markdown]
# # Looking at MPG over Time

# %%
ax = df.plot(kind="scatter", x='year', y='mpg');
ax.set_title('Scatterplot of MPG by Year');

# %%
ax = sns.stripplot(data=df, x='year', y='mpg')
ax.set_title('Stripplot of MPG by Year');
plt.xticks(rotation=45);

# %%
ax = sns.boxplot(data=df, x='year', y='mpg')
ax.set_title("Boxplot of MPG by Year");
plt.xticks(rotation=45);

# %%
df.query('year=="1978" and mpg > 40')
# Out:
# Empty DataFrame
# Columns: [name, cylinders, weight, year, territory, acceleration, mpg, hp, displacement, cylinders_label]
# Index: []

# %%
ax = sns.scatterplot(data=df, x='year', y='mpg', size='weight')
ax.set_title('Stripplot of MPG by Year');

# %%
ax = sns.scatterplot(data=df, x='year', y='mpg', hue='weight')
ax.set_title('Stripplot of MPG by Year');

# %%
ax = sns.boxplot(data=df, x='year', y='weight')
ax.set_title('Boxplot of Weight by Year');
plt.xticks(rotation=45);

# %% [markdown]
# # Text analysis

# %%
df.head()
# Out:
#                         name  cylinders  weight  year territory  acceleration  \
# 0  Chevrolet Chevelle Malibu          8    3504  1970       USA          12.0
# 1          Buick Skylark 320          8    3693  1970       USA          11.5
# 2         Plymouth Satellite          8    3436  1970       USA          11.0
# 3              Amc Rebel Sst          8    3433  1970       USA          12.0
# 4                Ford Torino          8    3449  1970       USA          10.5
#
#     mpg     hp  displacement cylinders_label
# 0  18.0  130.0         307.0     8 cylinders
# 1  15.0  165.0         350.0     8 cylinders
# 2  18.0  150.0         318.0     8 cylinders
# 3  16.0  150.0         304.0     8 cylinders
# 4  17.0  140.0         302.0     8 cylinders

# %%
ser_car_makes = df.name.str.lower().str.split(n=1, expand=True)[0]
ser_car_makes.value_counts()[:10]
# Out:
# ford          48
# chevrolet     43
# plymouth      31
# dodge         28
# amc           27
# toyota        25
# datsun        23
# buick         17
# pontiac       16
# volkswagen    15
# Name: 0, dtype: int64

# %%
ser_car_makes.value_counts()[-10:]
# Out:
# cadillac     2
# bmw          2
# toyouta      1
# hi           1
# chevroelt    1
# capri        1
# maxda        1
# vokswagen    1
# triumph      1
# nissan       1
# Name: 0, dtype: int64

# %%
df['car_makes'] = ser_car_makes
ser_cars_by_territory = df[['territory', 'car_makes']].pivot_table(index=['territory', 'car_makes'], aggfunc='size')
df_cars_by_territory = pd.DataFrame(ser_cars_by_territory) # anonymous Series
df_cars_by_territory.columns = ['size'] # rename anonymous column 0 to a named column
df_cars_by_territory = df_cars_by_territory.sort_values(by=['territory', 'size'], ascending=False)
df_cars_by_territory
# Out:
#                          size
# territory car_makes
# USA       ford             48
#           chevrolet        43
#           plymouth         31
#           dodge            28
#           amc              27
#           buick            17
#           pontiac          16
#           mercury          11
#           oldsmobile       10
#           chrysler          6
#           chevy             3
#           cadillac          2
#           capri             1
#           chevroelt         1
#           hi                1
# Japan     toyota           25
#           datsun           23
#           honda            13
#           mazda             7
#           subaru            4
#           maxda             1
#           nissan            1
#           toyouta           1
# Europe    volkswagen       15
#           fiat              8
#           peugeot           8
#           volvo             6
#           vw                6
#           audi              5
#           opel              4
#           saab              4
#           renault           3
#           bmw               2
#           mercedes-benz     2
#           triumph           1
#           vokswagen         1

# %%
mask = df_cars_by_territory.apply(lambda x: x['size'] > 10, axis=1)
df_cars_by_territory[mask]
# Out:
#                       size
# territory car_makes
# USA       ford          48
#           chevrolet     43
#           plymouth      31
#           dodge         28
#           amc           27
#           buick         17
#           pontiac       16
#           mercury       11
# Japan     toyota        25
#           datsun        23
#           honda         13
# Europe    volkswagen    15

# %% [markdown]
# ## Report
#
# This report answers the following questions:
#
# * Is there a relationship between Weight and MPG - yes, with more weight we generally see lower MPG
# * Is there a relationship between Cylinders and Displacement - yes, with more Cylinders we see a higher Displacement
# * Is there a relationship between MPG and Years - yes, generally as we move from 1970 to 1982 we see steady improvements in MPG

# %%
print(f"df_raw had shape {df_raw.shape}, after dropping NaN entries we \
reduced from {df_raw.shape[0]} to {df.shape[0]} rows.")

assert ((df.mpg >= 7) & (df.mpg <=47)).all(), "Why do we see a wider range of MPG values now?"
assert ((df.year >= 1970) & (df.year <= 1982)).all(), "Why do we see a wider range of years now?"
# Out:
# df_raw had shape (406, 9), after dropping NaN entries we reduced from 406 to 385 rows.

# %% [markdown]
# As weight increases we see a decrease in MPG, this relationship is slightly non-linear with a faster decrease in MPG associated with low-to-mid Weight.

# %%
jg = sns.jointplot(data=df, x='weight', y='mpg').plot_joint(sns.kdeplot, zorder=0, n_levels=5)
jg.fig.suptitle('Density Estimate for MPG vs. Weight');

# %% [markdown]
# Acceleration gets worse as Horsepower decreases.

# %%
jg = sns.jointplot(data=df, x='acceleration', y='hp', kind='reg')
jg.fig.suptitle('Regression plot for Acceleration vs. Horsepower');

# %% [markdown]
# An engine's cubic inches of displacement is strongly related to the count of Cylinders.

# %%
ax = sns.boxplot(data=df, x='cylinders_label', y='displacement', order=sorted_cylinders_label, notch=True) 
sns.stripplot(data=df, x='cylinders_label', y='displacement', order=sorted_cylinders_label, alpha=0.5, ax=ax) 
ax.set_title("More Cylinders Generally Have\nHigher Cubic Inches of Displacement");

# %% [markdown]
# Heavier vehicles tend to have more Horsepower, the heaviest vehicles have the highest count of Cylinders.

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(data=df, x='weight', y='hp', hue='cylinders_label', 
                     hue_order=sorted_cylinders_label, ax=ax)
ax.set_title('Scatterplot of HP vs. Weight\nColoured by Cylinder Count');

# %% [markdown]
# Vehicle brands are strongly associated with Territory.

# %%
cm = sns.light_palette("green", as_cmap=True)
mask = df_cars_by_territory.apply(lambda x: x['size'] > 10, axis=1)
df_cars_by_territory[mask].style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_9b07d_row0_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_9b07d_row1_col0 {
#   background-color: #1f8f1f;
#   color: #f1f1f1;
# }
# #T_9b07d_row2_col0 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_9b07d_row3_col0 {
#   background-color: #7fbe7f;
#   color: #000000;
# }
# #T_9b07d_row4_col0 {
#   background-color: #85c185;
#   color: #000000;
# }
# #T_9b07d_row5_col0 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_9b07d_row6_col0 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_9b07d_row7_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_9b07d_row8_col0 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_9b07d_row9_col0 {
#   background-color: #9ece9e;
#   color: #000000;
# }
# #T_9b07d_row10_col0 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_9b07d_row11_col0 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# </style>
# <table id="T_9b07d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b07d_level0_col0" class="col_heading level0 col0" >size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >territory</th>
#       <th class="index_name level1" >car_makes</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b07d_level0_row0" class="row_heading level0 row0" rowspan="8">USA</th>
#       <th id="T_9b07d_level1_row0" class="row_heading level1 row0" >ford</th>
#       <td id="T_9b07d_row0_col0" class="data row0 col0" >48</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row1" class="row_heading level1 row1" >chevrolet</th>
#       <td id="T_9b07d_row1_col0" class="data row1 col0" >43</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row2" class="row_heading level1 row2" >plymouth</th>
#       <td id="T_9b07d_row2_col0" class="data row2 col0" >31</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row3" class="row_heading level1 row3" >dodge</th>
#       <td id="T_9b07d_row3_col0" class="data row3 col0" >28</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row4" class="row_heading level1 row4" >amc</th>
#       <td id="T_9b07d_row4_col0" class="data row4 col0" >27</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row5" class="row_heading level1 row5" >buick</th>
#       <td id="T_9b07d_row5_col0" class="data row5 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row6" class="row_heading level1 row6" >pontiac</th>
#       <td id="T_9b07d_row6_col0" class="data row6 col0" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row7" class="row_heading level1 row7" >mercury</th>
#       <td id="T_9b07d_row7_col0" class="data row7 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level0_row8" class="row_heading level0 row8" rowspan="3">Japan</th>
#       <th id="T_9b07d_level1_row8" class="row_heading level1 row8" >toyota</th>
#       <td id="T_9b07d_row8_col0" class="data row8 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row9" class="row_heading level1 row9" >datsun</th>
#       <td id="T_9b07d_row9_col0" class="data row9 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level1_row10" class="row_heading level1 row10" >honda</th>
#       <td id="T_9b07d_row10_col0" class="data row10 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9b07d_level0_row11" class="row_heading level0 row11" >Europe</th>
#       <th id="T_9b07d_level1_row11" class="row_heading level1 row11" >volkswagen</th>
#       <td id="T_9b07d_row11_col0" class="data row11 col0" >15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Vehicles from the USA consistently have worse MPG than corresponding vehicles from Japan or Europe in this sample. Vehicles in each territory become more efficient over the Years.

# %%
fg = sns.lmplot(data=df, x='year', y='mpg', hue='territory')
fg.fig.suptitle('MPG over Year by Territory');
